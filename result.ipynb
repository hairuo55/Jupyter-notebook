# %% [markdown]
# |  | F0 RMSE| MCD | V/UV | F0 CORR|
# | :---- | :----: | :----: | :----: | :----: |
# | 0.5pitch_dan|121.24Hz |3.332dB|18.637%|0.604|
# | 1pitch_dan | 51.041hZ | 3.145dB | 13.272%|0.863|
# | 1.5pitch_dan|112.449Hz | 3.719dB |18.708&|0.525|
# | 2pitch_dan | 97.77Hz|  3.474dB | 14.966% | 0.482 |
# | 0.5pitch_ste |94.858Hz | 3.136dB|37.444%|0.034|
# | 1pitch_ste |45.23Hz | 3.082dB | 16.286% | 0.780
# | 1.5pitch_ste | 96.214Hz | 3.54dB|20.785%|0.674|
# | 2pitch_ste | 159.248Hz | 4.074dB | 25.385% | 0.239 |

# %%
# %%html
# <img src="./source/dan_neutralnarrative00211.png",width=300,height=200>
# Out:
# <img src="./source/dan_neutralnarrative00211.png",width=300,height=200>

# %%
import IPython as ip
import librosa
y, sr= librosa.load('./source/dan_neutralnarrative00211_0.5pit.wav')
y1, sr1= librosa.load('./source/dan_neutralnarrative00211_1pit.wav')
y2, sr2= librosa.load('./source/dan_neutralnarrative00211_1.5pit.wav')
y3, sr3= librosa.load('./source/dan_neutralnarrative00211_2pit.wav')
ip.display.display(ip.display.Audio(y, rate=sr))
ip.display.display(ip.display.Audio(y1, rate=sr1))
ip.display.display(ip.display.Audio(y2, rate=sr2))
ip.display.display(ip.display.Audio(y3, rate=sr3))
# Out:
# c:\users\11326\appdata\local\programs\python\python38\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.10) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ...

# %%
# %%html
# <img src="./source/dan_neutralnarrative00030.png",width=300,height=200>
# Out:
# <img src="./source/dan_neutralnarrative00030.png",width=300,height=200>

# %%
# %%html
# <img src="./source/dan_confident00186.png",width=300,height=200>
# Out:
# <img src="./source/dan_confident00186.png",width=300,height=200>

# %%
# %%html
# <img src="./source/dan_amazed01285.png",width=300,height=200>
# Out:
# <img src="./source/dan_amazed01285.png",width=300,height=200>

# %%
import IPython as ip
import librosa
y, sr= librosa.load('./source/dan_amazed01285_0.5pit.wav')
y1, sr1= librosa.load('./source/dan_amazed01285_1pit.wav')
y2, sr2= librosa.load('./source/dan_amazed01285_1.5pit.wav')
y3, sr3= librosa.load('./source/dan_amazed01285_2pit.wav')
ip.display.display(ip.display.Audio(y, rate=sr))
ip.display.display(ip.display.Audio(y1, rate=sr1))
ip.display.display(ip.display.Audio(y2, rate=sr2))
ip.display.display(ip.display.Audio(y3, rate=sr3))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%html
# <img src="./source/ste_neutralnarrative00597.png",width=300,height=200>
# Out:
# <img src="./source/ste_neutralnarrative00597.png",width=300,height=200>

# %%
import IPython as ip
import librosa
y, sr= librosa.load('./source/ste_neutralnarrative00597_0.5pit.wav')
y1, sr1= librosa.load('./source/ste_neutralnarrative00597_1pit.wav')
y2, sr2= librosa.load('./source/ste_neutralnarrative00597_1.5pit.wav')
y3, sr3= librosa.load('./source/ste_neutralnarrative00597_2pit.wav')
ip.display.display(ip.display.Audio(y, rate=sr))
ip.display.display(ip.display.Audio(y1, rate=sr1))
ip.display.display(ip.display.Audio(y2, rate=sr2))
ip.display.display(ip.display.Audio(y3, rate=sr3))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%html
# <img src="./source/ste_neutralpresenting00017.png",width=300,height=200>
# Out:
# <img src="./source/ste_neutralpresenting00017.png",width=300,height=200>

# %%
# %%html
# <img src="./source/ste_amazed00170.png",width=300,height=200>
# Out:
# <img src="./source/ste_amazed00170.png",width=300,height=200>

# %%
import IPython as ip
import librosa
y, sr= librosa.load('./source/ste_amazed00170_0.5pit.wav')
y1, sr1= librosa.load('./source/ste_amazed00170_1pit.wav')
y2, sr2= librosa.load('./source/ste_amazed00170_1.5pit.wav')
y3, sr3= librosa.load('./source/ste_amazed00170_2pit.wav')
ip.display.display(ip.display.Audio(y, rate=sr))
ip.display.display(ip.display.Audio(y1, rate=sr1))
ip.display.display(ip.display.Audio(y2, rate=sr2))
ip.display.display(ip.display.Audio(y3, rate=sr3))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%html
# <img src="./source/ste_grief00174.png",width=300,height=200>
# Out:
# <img src="./source/ste_grief00174.png",width=300,height=200>
